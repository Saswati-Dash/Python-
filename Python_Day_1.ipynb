# %% [markdown]
# <a href="https://colab.research.google.com/github/Saswati-Dash/Python-/blob/main/Python_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to python")
 # it's an additional information
 # short cut command for executing the code --> ctrl+enter
 # shift+enter --> execute current code cell and add a new blank code cell
# Out:
# Welcome to python

# %%
98754554*5698745121525
# Out:
# 562777032835877174850

# %%
10+90
# Out:
# 100

# %%
# Python is an interpreted high level language .

# compiled --> 100 lines of code --> converted and executed once .--> 1

# intepreted --> Line by line execution .
# 100 lines of code --> one by one it is executed -->100

# compiled --> it is fast in execution , but terminates with the error , resulting in waste of
# computing resources , error identification is difficult .

# Intepreted --> code will not been terminated as whole , lines without error will be executed .
# Error identification is easy .

# %%
print('A')
print('B')
print(c)
print('D')
# Out:
# A
# B
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-220545392.py in <cell line: 0>()
#       1 print('A')
#       2 print('B')
# ----> 3 print(c)
#       4 print('D')
#
# NameError: name 'c' is not defined

# %%
S= 45
J=98.7

R= S+J

# %%
# 100 ---> int

# INT z =100

z=100
z="Rose"
z=90.8
z=1


# Python is Dynamically typed language .

# %%
type(z)
# Out:
# int

# %%
R
# Out:
# 143.7

# %%
S
# Out:
# 45

# %%
J
# Out:
# 98.7

# %%
R*2
# Out:
# 287.4

# %%
jin = 765

# %%
jin
# Out:
# 765

# %%
s=100

# %%
S='Tree'
S
# Out:
# 'Tree'

# %%
s
# Out:
# 100

# %%
# Data type of variable --> type(var)

type(S)
# Out:
# str

# %%
type(J)
# Out:
# float

# %%
# 3 Golden rules for defining variable .

# 1. Varibale name should not be as same as inbuilt function or keywords.(For, IF , Def)

# %%
print=500

# %%
type(print)
# Out:
# int

# %%
print('Hello everyone')
# Out:
# Hello everyone

# %%
del print # r4estore the original functionality .

# %%
# 2 . Variable should always starts with underscore or an alphabet , it will never
# start with a number .


E1='Henry'

# %%
E1
# Out:
# 'Henry'

# %%
# 3. Varibale name can only have _ as special symbol , no other symbol is allowed
# #$%^&*spaces or , /?.

Fire$fury=4578
# Out:
#   File "/tmp/ipython-input-2358394461.py", line 4
#     Fire$fury=4578
#         ^
# SyntaxError: invalid syntax

# %%
a=90
a=67
a=87

# %%
a
# Out:
# 87

# %%
Age=int(input('Enter the Age'))
# Out:
# Enter the Age56.34
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-847310276.py in <cell line: 0>()
# ----> 1 Age=int(input('Enter the Age'))
#
# ValueError: invalid literal for int() with base 10: '56.34'

# %%
Age
# Out:
# 45

# %%
type(Age)
# Out:
# int

# %%
Age+10
# Out:
# 55

# %%
# conversion --> Str --> int
# Str---> Float

# %%
int(56.34)
# Out:
# 56

# %%
Marks =float(input('Enter the marks'))
# Out:
# Enter the marks80

# %%
Marks
# Out:
# 80.0

# %%
80.0*50
# Out:
# 4000.0

# %%
80*50
# Out:
# 4000

# %%
56.34*50
# Out:
# 2817.0

# %%
56*50
# Out:
# 2800

# %%
# Retail stores --> bill calcuation .

Quantity=int(input('Enter the number of product'))
Price = float(input('Enter the price of the product'))
billing_amount=Quantity*Price
billing_amount
# Out:
# Enter the number of product98
# Enter the price of the product524
# 51352.0

# %%
# Set --> collection of unique information .

x={True,1,1,True,True,8,9,0,False}

# ---> Left to right ---> execution .

# %%
x
# Out:
# {0, True, 8, 9}

# %%
# Indexing "",''

s="Python"

# %%
s
# Out:
# 'Python'

# %%
# it's raining

r="it's raining"

# %%
r
# Out:
# "it's raining"

# %%
s
# Out:
# 'Python'

# %%
s[4]
# Out:
# 'o'

# %%
s[-2]
# Out:
# 'o'

# %%
t= 'pneumonoultramicroscopicsilicovolcanoconiosis'

# %%
t[-3]
# Out:
# 's'

# %%
t[8]
# Out:
# 'u'

# %%
s
# Out:
# 'Python'

# %%
# slicing

s[2:4]
# Out:
# 'th'

# %%
s[2:5]
# Out:
# 'tho'

# %%
s[-3:]

# -3 :-2
# Out:
# 'hon'

# %%
-1-1
# Out:
# -2

# %%
s[:5] # 0,1,2,3,4

# start  index is not given --> 0
# Out:
# 'Pytho'

# %%
s[2:] # 2 ----> end

# End index is not given --> access till the end .
# Out:
# 'thon'

# %%
s[:]
# Out:
# 'Python'

# %%
# Immutable --> Non changeable

s
# Out:
# 'Python'

# %%
type(s)
# Out:
# str

# %%
s[1]='C'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2764093542.py in <cell line: 0>()
# ----> 1 s[1]='C'
#
# TypeError: 'str' object does not support item assignment

# %%
s=90

# %%
s
# Out:
# 90

# %%
s='JAVA'

# %%
s[0]="K"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-965900866.py in <cell line: 0>()
# ----> 1 s[0]="K"
#
# TypeError: 'str' object does not support item assignment

# %%
# Mutable Format .

# List : collection of different data types to be stored together .

# Var_name = [e1,e2,e3,e4,e5]

lime=['John',45,45863.21,'Chicago',True]

# %%
lime
# Out:
# ['John', 45, 45863.21, 'Chicago', True]

# %%
type(lime)
# Out:
# list

# %%
lime[2]
# Out:
# 45863.21

# %%
lime[:4]
# Out:
# ['John', 45, 45863.21, 'Chicago']

# %%
# Change the salary of the employee.

lime
# Out:
# ['John', 45, 45863.21, 'Chicago', True]

# %%
lime[2]=60000

# %%
lime
# Out:
# ['John', 45, 60000, 'Chicago', True]

# %%
# Tuple : collection of different data types to be stored together.

# %%
# syntax : var_name = (e1,e2,e3,e4,e5--e6)

# %%
hit=('John',45,45863.21,'Chicago',True)

# %%
hit
# Out:
# ('John', 45, 45863.21, 'Chicago', True)

# %%
type(hit)
# Out:
# tuple

# %%
hit[2]=60000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1097442450.py in <cell line: 0>()
# ----> 1 hit[2]=60000
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Indexiing and slicing = []
# Tuple = ()
# List = []
# set ={}
