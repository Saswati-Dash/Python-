# %% [markdown]
# <a href="https://colab.research.google.com/github/Saswati-Dash/Python-/blob/main/Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Python")
# use for commenting
''' multi line comment
hitt4rjij
jfrkjjtrjh
jkhfhjf '''
# short cut for executing the cell - ctrl + enter or shift + enter
# shift + enter - run current code cell and add blank code cell
# Out:
# Welcome to Python
# ' multi line comment\nhitt4rjij\njfrkjjtrjh\njkhfhjf '

# %%
del print # del - restore original personality -- ex - del print

# %%
age = input('Enter the age')
# Out:
# Enter the age24

# %%
age
# Out:
# '24'

# %%
type(age)
# Out:
# str

# %%
# convertion ->  str - int

# %%
age = int(input('Enter the age'))
# Out:
# Enter the age24

# %%
age
# Out:
# 24

# %%
Mark = float(input('enter mark '))
# Out:
# enter mark 55

# %%
# 3 Golden rule to define variable
# Varible should not be as same as inbuilt function or keyword
# Varibale should start with underscore _ or an alphabet , but it will not start with a number
# varibale name can only have _ as special symbol no other special symbol is allowed

# %%
type(k)
# Out:
# int

# %%
k
# Out:
# 21

# %%
print = 100

# %%
print
# Out:
# 100

# %%
# python is a interpreted high level language
# compiled - 100 line of code is executed once - converted and executed once
# interpreted - line by line execution -> 100 line of code -> one by one is executed i.ed 100 execution
# complied is fast in execution but termination with error , result in computing resourse , error identification is difficult
# interpreted - error will not be terminated as whole , line without error will be executed ,error identification is easy

# %%
# data type - type(variable)
s = 10
j = 11
k = s + j

# %%
s
# Out:
# 10
