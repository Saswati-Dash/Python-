# %% [markdown]
# <a href="https://colab.research.google.com/github/Saswati-Dash/Python-/blob/main/DPP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
annual_ctc=float(input('Enter the annual CTC'))
tax=0.1*annual_ctc
pf=0.05*annual_ctc

annual_in_hand= annual_ctc-tax-pf
Monthly_in_hand= annual_in_hand/12

print("Monthly salary",Monthly_in_hand)
print("Total Tax",tax)
print("PF deductions",pf)
# Out:
# Enter the annual CTC800000
# Monthly salary 56666.666666666664
# Total Tax 80000.0
# PF deductions 40000.0

# %%
#  subtract = 10 % CTC for TAX .

# 1000 ---> 10 % ---> 100

# 1

# 1000 *1 = 1000
#1000*0.9=900
#
# Out:
# 1200000.0

# %%
# Regular or positive indexes --> 0 ---> 1.
# first value will be stored at 0 index --> left to right +1
# Reverse or negative indexes ---> -1 ---> -2 .
# End of collection and moves from right to left , decrtementing by 1 .

fire=[156,'Kite',True,90.8,'Thuder',65]

# %%
fire
# Out:
# [156, 'Kite', True, 90.8, 'Thuder', 65]

# %%
fire[-1]
# Out:
# 65

# %%
fire[-3]
# Out:
# 90.8

# %%
fire[0]
# Out:
# 156

# %%
fire[5]
# Out:
# 65

# %%
fire[-1]
# Out:
# 65

# %%
# slicing
fire[1:4]
# Out:
# ['Kite', True, 90.8]

# %%
fire
# Out:
# [156, 'Kite', True, 90.8, 'Thuder', 65]

# %%
fire[4][2]
# Out:
# 'u'

# %%
fire[-2][1:4]
# Out:
# 'hud'

# %%
# Mutuable data format .

# List

# Dictionary : Helps to manage and store the information in organised way .

# Helps to define user defined indexes ---> ?????
# default indexes ---> Positive and negative intergers .

# used to store information in key value pair format .

# key ---> indexes .(no duplicate keys )
# value --> information .


# Syntax : var_name= {K1:V1,K2:V2------Kn:vn}

# %%
tree={'a':900,78.5:"Apple",'a':432,True:900}

# %%
tree
# Out:
# {'a': 432, 78.5: 'Apple', True: 900}

# %%
tree['a']
# Out:
# 900

# %%
tree[78.5][]
# Out:
# 'pple'

# %%
tree[True]
# Out:
# 900

# %%
# Price of 6 products .

w_p=[98,241,74,56,38,46]

# %%
w_p
# Out:
# [98, 241, 74, 56, 38, 46]

# %%
w_p_d={'Oats':98,'Headphone':241,'Cake':74,'Butter':56,'Honey':38,'Choclates':46}

# %%
w_p_d
# Out:
# {'Oats': 98,
#  'Headphone': 241,
#  'Cake': 74,
#  'Butter': 56,
#  'Honey': 38,
#  'Choclates': 46}

# %%
w_p_d['Oats']=86

# %%
w_p_d['Honey']
# Out:
# 38

# %%
w_p_d
# Out:
# {'Oats': 86,
#  'Headphone': 241,
#  'Cake': 74,
#  'Butter': 56,
#  'Honey': 38,
#  'Choclates': 46}

# %%
# Data using dictionary .

std={'Name':['John','Alex','Henry','Yoda'],'Marks':[78,89,92,61],'Grade':['B','B','A','C']}

# %%
std
# Out:
# {'Name': ['John', 'Dev', 'Henry', 'Yoda'],
#  'Marks': [78, 89, 92, 61],
#  'Grade': ['B', 'B', 'A', 'C']}

# %%
std['Name'][1]="Dev"

# %%
import pandas

# %%
pandas.DataFrame(std)
# Out:
#     Name  Marks Grade
# 0   John     78     B
# 1    Dev     89     B
# 2  Henry     92     A
# 3   Yoda     61     C

# %%
w_p
# Out:
# [98, 241, 74, 56, 38, 46]

# %%
w_p.remove(56) # element itself

# %%
w_p
# Out:
# [98, 241, 74, 38, 46]

# %%
w_p.pop(-1) # index of element
# Out:
# 46

# %%
w_p
# Out:
# [98, 241, 74, 38]

# %%
w_p_d
# Out:
# {'Oats': 86,
#  'Headphone': 241,
#  'Cake': 74,
#  'Butter': 56,
#  'Honey': 38,
#  'Choclates': 46}

# %%
w_p_d.pop('Butter')
# Out:
# 56

# %%
w_p_d
# Out:
# {'Oats': 86, 'Headphone': 241, 'Cake': 74, 'Honey': 38, 'Choclates': 46}

# %%
w_p.remove(241)

# %%
w_p
# Out:
# [98, 74, 38]

# %%
w_p
# Out:
# [98, 74, 98, 38]

# %%
# Set : Unordered collection of unique values .

# syntax: {e1,e2,e3,e4,e5,e6}

s1={'Rose',5,4,5,8,7,63.2,65.3,47,58.2,98.5,'Rose'}

# %%
s1
# Out:
# {4, 47, 5, 58.2, 63.2, 65.3, 7, 8, 98.5, 'Rose'}

# %%
# Brackets :

# LIST=[]
#Tuple=()
# Dictionary={k:v}
#set={E1,E2}
