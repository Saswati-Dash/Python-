# %% [markdown]
# <a href="https://colab.research.google.com/github/Saswati-Dash/Python-/blob/main/P_Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Set --> Collection of unique information
x = {1,1,1,8,8,0,7,True,True,False,False}
# here 1 & true are same and 0 & false are same
# execute from left to right

# %%
x
# Out:
# {0, 1, 7, 8}

# %%
#Indexing
s= 'Python'

# %%
s[2]
# Out:
# 't'

# %%
s[2:5]
# Out:
# 'tho'

# %%
s= 'pcthon'

# %%
s
# Out:
# 'pcthon'

# %%
s[1] = 'y'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1410519016.py in <cell line: 0>()
# ----> 1 s[1] = 'y'
#
# TypeError: 'str' object does not support item assignment

# %%
# Mutable format
#List :- collection of different data types to be stored together
# var_name = [e1,e2,e3,e4]
lime = ['John' , 45 , 45863.21,'Chicago',True]

# %%
lime
# Out:
# ['John', 45, 45863.21, 'Chicago', True]

# %%
type(lime)
# Out:
# list

# %%
lime[2]
# Out:
# 45863.21

# %%
lime[:4]
# Out:
# ['John', 45, 45863.21, 'Chicago']

# %%
# Salary of the  employee
lime[2] = 60000

# %%
lime
# Out:
# ['John', 45, 60000, 'Chicago', True]

# %%
# Tuple : collection of different data types to be stored together . it is immutable
# syntax -var_name = (e1,e2,e3,e4,e5)

# %%
hit = ('John' , 45 , 45863.21,'Chicago',True)

# %%
type(hit)
# Out:
# tuple

# %%
hit[2]
# Out:
# 45863.21

# %%
hit[2] = 60000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-20744049.py in <cell line: 0>()
# ----> 1 hit[2] = 60000
#
# TypeError: 'tuple' object does not support item assignment

# %%
# indexing & slicing = []
# Tuple = ()
# list = []
# set = {}
